# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
import mmcv
# Out:
# WARNING: CPU random generator seem to be failing, disabling hardware random number generation
# WARNING: RDRND generated: 0xffffffff 0xffffffff 0xffffffff 0xffffffff

# %%
config_file = '/root/mmdetection/configs/ssd/finetune.py'
# download the checkpoint from model zoo and put it in `checkpoints/`
# url: https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
# config_file = '/root/mmdetection/configs/ssd/ssdlite_mobilenetv2_scratch_600e_coco.py'
# checkpoint_file = '../checkpoints/ssdlite_mobilenetv2_scratch_600e_coco_20210629_110627-974d9307.pth'
checkpoint_file = '../frozen-finetune/epoch_10.pth'

# %%
# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda')
# Out:
# load checkpoint from local path: ../frozen-finetune/epoch_1.pth

# %%
# test a single image
img = '../dogs.jpg'
# img = '../data/coco/test2017/000000158343.jpg' # 2 skilia
# img = '../data/coco/test2017/000000543135.jpg'
result = inference_detector(model, img)

# %%
# show the results
show_result_pyplot(model, img, result, score_thr=0.5)
